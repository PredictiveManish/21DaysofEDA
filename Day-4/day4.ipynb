# %% [markdown]
# ## Feature Engineering

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tested.csv')
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 61           953         0       2
# 179         1071         1       1
# 382         1274         1       3
# 330         1222         1       2
# 91           983         0       3
# 316         1208         0       1
# 234         1126         0       1
# 233         1125         0       3
# 285         1177         0       3
# 339         1231         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 61                           McCrae, Mr. Arthur Gordon    male  32.0      0
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 382                         Risien, Mrs. Samuel (Emma)  female   NaN      0
# 330  Davies, Mrs. John Morgan (Elizabeth Agnes Mary...  female  48.0      0
# 91                                  Pedersen, Mr. Olaf    male   NaN      0
# 316                      Spencer, Mr. William Augustus    male  57.0      1
# ...

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'B45', 'E31', 'B57 B59 B63 B66', 'B36', 'A21', 'C78', 'D34',
#        'D19', 'A9', 'D15', 'C31', 'C23 C25 C27', 'F G63', 'B61', 'C53',
#        'D43', 'C130', 'C132', 'C101', 'C55 C57', 'B71', 'C46', 'C116',
#        'F', 'A29', 'G6', 'C6', 'C28', 'C51', 'E46', 'C54', 'C97', 'D22',
#        'B10', 'F4', 'E45', 'E52', 'D30', 'B58 B60', 'E34', 'C62 C64',
#        'A11', 'B11', 'C80', 'F33', 'C85', 'D37', 'C86', 'D21', 'C89',
#        'F E46', 'A34', 'D', 'B26', 'C22 C26', 'B69', 'C32', 'B78',
#        'F E57', 'F2', 'A18', 'C106', 'B51 B53 B55', 'D10 D12', 'E60',
#        'E50', 'E39 E41', 'B52 B54 B56', 'C39', 'B24', 'D28', 'B41', 'C7',
#        'D40', 'D38', 'C105'], dtype=object)

# %% [markdown]
# ## Pairing- Siblings/Spouse(SibSp) + Parent CHild (parch) + self = Family

# %%
df['Family'] = df['SibSp'] + df['Parch'] + 1
df.drop(columns=['SibSp', 'Parch'], inplace=True)

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  \
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# ...

# %%
df['FarePerPerson'] = df['Fare']/df['Family']
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  \
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# ...

# %% [markdown]
# ### Missing Value Handling

# %%
type(df)
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Family', 'FarePerPerson'],
#       dtype='object')

# %%
df['Age'].fillna(df['Age'].median())
df['Embarked'].fillna('Unknown')
while 'Unknown' in df['Embarked'].values:
    print(df[df['Embarked'] == 'Unknown'])
    break  # prevent infinite loop

# %%
df.sample(20)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0            892         0       3                         Kelly, Mr. James
# 17           909         0       3                        Assaf, Mr. Gerios
# 199         1091         1       3  Rasmussen, Mrs. (Lena Jacobsen Solvang)
# 293         1185         0       1                    Dodge, Dr. Washington
# 269         1161         0       3                        Pokrnic, Mr. Mate
# 157         1049         1       3                 Lundin, Miss. Olga Elida
# 270         1162         0       1             McCaffry, Mr. Thomas Francis
# 67           959         0       1           Moore, Mr. Clarence Bloomfield
# 107          999         0       3                         Ryan, Mr. Edward
# 62           954         0       3             Bjorklund, Mr. Ernst Herbert
# 19           911         1       3    Assaf Khalil, Mrs. Mariana (Miriam")"
# ...

# %%
df['FareRange'] = pd.qcut(df['Fare'], 4, labels=['Low', 'Med', 'High', 'Very High'])
df['FareRange']
# Out:
# 0            Low
# 1            Low
# 2            Med
# 3            Med
# 4            Med
#          ...
# 413          Med
# 414    Very High
# 415          Low
# 416          Med
# 417         High
# Name: FareRange, Length: 418, dtype: category
# Categories (4, object): ['Low' < 'Med' < 'High' < 'Very High']

# %%
df['FareperpersonRange'] = pd.qcut(df['FarePerPerson'], 3, labels=['Low','Average','High'])

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age   Ticket  \
# 0                              Kelly, Mr. James    male  34.5   330911
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0   363272
# 2                     Myles, Mr. Thomas Francis    male  62.0   240276
# 3                              Wirz, Mr. Albert    male  27.0   315154
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0  3101298
#
#       Fare Cabin Embarked  Family  FarePerPerson FareRange FareperpersonRange
# 0   7.8292   NaN        Q       1       7.829200       Low            Average
# 1   7.0000   NaN        S       2       3.500000       Low                Low
# 2   9.6875   NaN        Q       1       9.687500       Med            Average
# ...

# %%
df = pd.get_dummies(df, columns=['Embarked', 'Pclass'], drop_first=True)

# %%
df.head()
# Out:
#    PassengerId  Survived                                          Name  \
# 0          892         0                              Kelly, Mr. James
# 1          893         1              Wilkes, Mrs. James (Ellen Needs)
# 2          894         0                     Myles, Mr. Thomas Francis
# 3          895         0                              Wirz, Mr. Albert
# 4          896         1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#       Sex   Age   Ticket     Fare Cabin  Family  FarePerPerson FareRange  \
# 0    male  34.5   330911   7.8292   NaN       1       7.829200       Low
# 1  female  47.0   363272   7.0000   NaN       2       3.500000       Low
# 2    male  62.0   240276   9.6875   NaN       1       9.687500       Med
# 3    male  27.0   315154   8.6625   NaN       1       8.662500       Med
# 4  female  22.0  3101298  12.2875   NaN       3       4.095833       Med
#
#    Embarked_Q  Embarked_S  Pclass_2  Pclass_3
# 0        True       False     False      True
# ...

# %% [markdown]
# ## Mapping Ordinal Features

# %%
df['CabinLevel']= df['Cabin'].str[0]
cabins = {'A':1, 'B':2, 'C':3, 'D':4, 'E':5, 'F':6, 'G':7, 'T':8, np.nan:0}
df['CabinLevel'] = df['CabinLevel'].map(cabins)
df.sample(10)
# Out:
#      PassengerId  Survived                                               Name  \
# 56           948         0                                    Cor, Mr. Bartol
# 8            900         1          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 55           947         0                               Rice, Master. Albert
# 171         1063         0                                Zakarian, Mr. Ortin
# 389         1281         0                        Palsson, Master. Paul Folke
# 100          992         1  Stengel, Mrs. Charles Emil Henry (Annie May Mo...
# 68           960         0                    Tucker, Mr. Gilbert Milligan Jr
# 5            897         0                         Svensson, Mr. Johan Cervin
# 416         1308         0                                Ware, Mr. Frederick
# 400         1292         1                            Bonnell, Miss. Caroline
#
#         Sex   Age  Ticket      Fare Cabin  Family  FarePerPerson  FareRange  \
# ...

# %%
df.sample(10)
# Out:
#      PassengerId  Survived                                     Name     Sex  \
# 209         1101         0                       Delalic, Mr. Redjo    male
# 232         1124         0                  Wiklund, Mr. Karl Johan    male
# 360         1252         0              Sage, Master. William Henry    male
# 66           958         1                  Burns, Miss. Mary Delia  female
# 368         1260         1  Gibson, Mrs. Leonard (Pauline C Boeson)  female
# 198         1090         0           Baimbrigge, Mr. Charles Robert    male
# 79           971         1                   Doyle, Miss. Elizabeth  female
# 306         1198         0     Allison, Mr. Hudson Joshua Creighton    male
# 355         1247         0                 Julian, Mr. Henry Forbes    male
# 9            901         0                  Davies, Mr. John Samuel    male
#
#       Age      Ticket      Fare    Cabin  Family  FarePerPerson  FareRange  \
# ...
